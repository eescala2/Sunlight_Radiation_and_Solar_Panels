# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine
alchemyEngine = create_engine('postgresql+psycopg2://postgres:msuproject@solarmsuproject.cfrh4os4lzss.us-east-1.rds.amazonaws.com:5432/<password>', pool_recycle=3600);
#('postgresql://postgres:msuproject@solarmsuproject.cfrh4os4lzss.us-east-1.rds.amazonaws.com:5432/<password>')

# %%
dbConnection=alchemyEngine.connect();

# %%
dataFrame=pd.read_sql("select * from \"complete_deep_solar_and_demographics_mich\"", dbConnection);

# %%
pd.set_option('display.expand_frame_repr', False);
del dataFrame['county']

# %%
print(dataFrame);
# Out:
#       tile_count  solar_system_count  total_panel_area         fips  solar_panel_area_divided_by_area  solar_panel_area_per_capita  tile_count_residential  solar_system_count_residential  total_panel_area_residential     lat     lon  daily_solar_radiation  number_of_solar_system_per_household  median_income  education_level  homeownership  population_density
# 0              0                   0          0.000000  26007000900                          0.000000                     0.000000                       0                               0                      0.000000  44.956 -83.381                   3.59                              0.000000        42792.0             17.5          80.07                19.1
# 1              0                   0          0.000000  26007990000                          0.000000                          NaN                       0                               0                      0.000000     NaN     NaN                    NaN                                   NaN        42792.0             17.5          80.07                19.1
# 2              0                   0          0.000000  26007000400                          0.000000                     0.000000                       0                               0                      0.000000  45.069 -83.418                   3.73                              0.000000        42792.0             17.5          80.07                19.1
# 3              0                   0          0.000000  26007000100                          0.000000                     0.000000                       0                               0                      0.000000  45.031 -83.657                   3.73                              0.000000        42792.0             17.5          80.07                19.1
# 4              2                   1         42.860100  26007000200                          0.277859                     0.010033                       2                               1                     42.860100  45.054 -83.593                   3.73                              0.000558        42792.0             17.5          80.07                19.1
# ...          ...                 ...               ...          ...                               ...                          ...                     ...                             ...                           ...     ...     ...                    ...                                   ...            ...              ...            ...                 ...
# 1775           0                   0          0.000000  54099020800                          0.000000                     0.000000                       0                               0                      0.000000  38.089 -82.524                   3.83                              0.000000        46440.0             23.3          64.01              1103.0
# 1776           0                   0          0.000000  54099020900                          0.000000                     0.000000                       0                               0                      0.000000  38.138 -82.360                   3.83                              0.000000        46440.0             23.3          64.01              1103.0
# 1777           0                   0          0.000000  54099021000                          0.000000                     0.000000                       0                               0                      0.000000  37.969 -82.353                   3.87                              0.000000        46440.0             23.3          64.01              1103.0
# 1778           2                   2         61.978748  54099005100                         66.261705                     0.031192                       2                               2                     61.978748  38.403 -82.521                   3.83                              0.002410        46440.0             23.3          64.01              1103.0
# 1779           1                   1         46.398253  54099005200                         54.688719                     0.024628                       1                               1                     46.398253  38.398 -82.524                   3.83                              0.001302        46440.0             23.3          64.01              1103.0
#
# [1780 rows x 17 columns]

# %%
dataFrame.head()
# Out:
#    tile_count  solar_system_count  total_panel_area         fips  solar_panel_area_divided_by_area  solar_panel_area_per_capita  tile_count_residential  solar_system_count_residential  total_panel_area_residential     lat     lon  daily_solar_radiation  number_of_solar_system_per_household  median_income  education_level  homeownership  population_density
# 0           0                   0            0.0000  26007000900                          0.000000                     0.000000                       0                               0                        0.0000  44.956 -83.381                   3.59                              0.000000        42792.0             17.5          80.07                19.1
# 1           0                   0            0.0000  26007990000                          0.000000                          NaN                       0                               0                        0.0000     NaN     NaN                    NaN                                   NaN        42792.0             17.5          80.07                19.1
# 2           0                   0            0.0000  26007000400                          0.000000                     0.000000                       0                               0                        0.0000  45.069 -83.418                   3.73                              0.000000        42792.0             17.5          80.07                19.1
# 3           0                   0            0.0000  26007000100                          0.000000                     0.000000                       0                               0                        0.0000  45.031 -83.657                   3.73                              0.000000        42792.0             17.5          80.07                19.1
# 4           2                   1           42.8601  26007000200                          0.277859                     0.010033                       2                               1                       42.8601  45.054 -83.593                   3.73                              0.000558        42792.0             17.5          80.07                19.1

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn import linear_model
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
shape=dataFrame.shape
print("Dataset contains {} rows and {} columns".format(shape[0],shape[1]))
# Out:
# Dataset contains 1780 rows and 17 columns

# %%
dataFrame
# Out:
#       tile_count  solar_system_count  total_panel_area         fips  solar_panel_area_divided_by_area  solar_panel_area_per_capita  tile_count_residential  solar_system_count_residential  total_panel_area_residential     lat     lon  daily_solar_radiation  number_of_solar_system_per_household  median_income  education_level  homeownership  population_density
# 0              0                   0          0.000000  26007000900                          0.000000                     0.000000                       0                               0                      0.000000  44.956 -83.381                   3.59                              0.000000        42792.0             17.5          80.07                19.1
# 1              0                   0          0.000000  26007990000                          0.000000                          NaN                       0                               0                      0.000000     NaN     NaN                    NaN                                   NaN        42792.0             17.5          80.07                19.1
# 2              0                   0          0.000000  26007000400                          0.000000                     0.000000                       0                               0                      0.000000  45.069 -83.418                   3.73                              0.000000        42792.0             17.5          80.07                19.1
# 3              0                   0          0.000000  26007000100                          0.000000                     0.000000                       0                               0                      0.000000  45.031 -83.657                   3.73                              0.000000        42792.0             17.5          80.07                19.1
# 4              2                   1         42.860100  26007000200                          0.277859                     0.010033                       2                               1                     42.860100  45.054 -83.593                   3.73                              0.000558        42792.0             17.5          80.07                19.1
# ...          ...                 ...               ...          ...                               ...                          ...                     ...                             ...                           ...     ...     ...                    ...                                   ...            ...              ...            ...                 ...
# 1775           0                   0          0.000000  54099020800                          0.000000                     0.000000                       0                               0                      0.000000  38.089 -82.524                   3.83                              0.000000        46440.0             23.3          64.01              1103.0
# 1776           0                   0          0.000000  54099020900                          0.000000                     0.000000                       0                               0                      0.000000  38.138 -82.360                   3.83                              0.000000        46440.0             23.3          64.01              1103.0
# 1777           0                   0          0.000000  54099021000                          0.000000                     0.000000                       0                               0                      0.000000  37.969 -82.353                   3.87                              0.000000        46440.0             23.3          64.01              1103.0
# 1778           2                   2         61.978748  54099005100                         66.261705                     0.031192                       2                               2                     61.978748  38.403 -82.521                   3.83                              0.002410        46440.0             23.3          64.01              1103.0
# 1779           1                   1         46.398253  54099005200                         54.688719                     0.024628                       1                               1                     46.398253  38.398 -82.524                   3.83                              0.001302        46440.0             23.3          64.01              1103.0
#
# [1780 rows x 17 columns]

# %%
dataFrame.columns
# Out:
# Index(['tile_count', 'solar_system_count', 'total_panel_area', 'fips',
#        'solar_panel_area_divided_by_area', 'solar_panel_area_per_capita',
#        'tile_count_residential', 'solar_system_count_residential',
#        'total_panel_area_residential', 'lat', 'lon', 'daily_solar_radiation',
#        'number_of_solar_system_per_household', 'median_income',
#        'education_level', 'homeownership', 'population_density'],
#       dtype='object')

# %%
dataFrame.describe()
# Out:
#         tile_count  solar_system_count  total_panel_area  solar_panel_area_divided_by_area  solar_panel_area_per_capita  tile_count_residential  solar_system_count_residential  total_panel_area_residential          lat          lon  daily_solar_radiation  number_of_solar_system_per_household  median_income  education_level  homeownership  population_density
# count  1780.000000         1780.000000       1780.000000                       1780.000000                  1755.000000             1780.000000                     1780.000000                   1780.000000  1671.000000  1671.000000            1671.000000                           1750.000000    1780.000000      1780.000000    1780.000000         1780.000000
# mean      5.013483            2.765169        338.646054                         30.454397                     0.033384                2.471910                        2.143258                     48.205813    41.888937   -83.203370               3.725817                              0.003032   49085.225843        31.299775      68.350949          661.279157
# std      26.117343            6.056500       3590.078467                         73.099709                     0.643681                4.507666                        3.537518                     98.150622     2.236433     2.961192               0.162529                              0.034999    7869.006162        11.128753       5.124874          407.365998
# min       0.000000            0.000000          0.000000                          0.000000                     0.000000                0.000000                        0.000000                      0.000000    28.337000  -110.867000               3.450000                              0.000000   39934.000000        17.500000      60.630000            4.100000
# 25%       0.000000            0.000000          0.000000                          0.000000                     0.000000                0.000000                        0.000000                      0.000000    42.266000   -83.720000               3.670000                              0.000000   46440.000000        23.300000      64.010000          245.500000
# 50%       1.000000            1.000000         25.365807                          6.411197                     0.005424                1.000000                        1.000000                     17.265710    42.403000   -83.302000               3.670000                              0.000867   46440.000000        23.300000      64.550000          556.100000
# 75%       4.000000            3.000000        107.419550                         36.940856                     0.016715                3.000000                        3.000000                     59.495679    42.664500   -83.126000               3.730000                              0.002058   48413.000000        38.500000      72.890000         1103.000000
# max     707.000000          162.000000     110997.437200                       2018.658717                    25.276022               66.000000                       49.000000                   1397.798345    46.615000   -71.375000               4.970000                              1.000000   69434.000000        55.200000      80.490000         1103.000000

# %%
dataFrame = dataFrame.fillna(0)

# %%
from sklearn.model_selection import train_test_split
np.random.seed(0)
df_train, df_test = train_test_split(dataFrame, train_size=0.7, test_size=0.3, random_state=100)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
numerical_variables=['daily_solar_radiation','median_income', 'education_level', 'homeownership','population_density', 'solar_system_count_residential', 'number_of_solar_system_per_household', 'solar_system_count']
df_train[numerical_variables]=scaler.fit_transform(df_train[numerical_variables])

df_train
# Out:
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
#       tile_count  solar_system_count  total_panel_area         fips  solar_panel_area_divided_by_area  solar_panel_area_per_capita  tile_count_residential  solar_system_count_residential  total_panel_area_residential     lat     lon  daily_solar_radiation  number_of_solar_system_per_household  median_income  education_level  homeownership  population_density
# 1345          13            0.049383        990.689706  26163586200                         14.955914                     0.015323                       6                        0.166667                    108.011413  42.212 -83.347               0.803063                              0.002715       0.220542         0.153846       0.170191            1.000000
# 1141           0            0.000000          0.000000  26163565200                          0.000000                     0.000000                       0                        0.000000                      0.000000  42.343 -83.420               0.803063                              0.000000       0.220542         0.153846       0.170191            1.000000
# 1039           1            0.006173        226.503502  26163545500                          0.000000                     0.000000                       0                        0.000000                      0.000000  42.347 -83.206               0.803063                              0.000000       0.220542         0.153846       0.170191            1.000000
# 924            9            0.043210        189.606261  26161402700                        145.476313                     0.034828                       9                        0.194444                    189.606261  42.313 -83.697               0.803063                              0.002977       1.000000         1.000000       0.197382            0.179088
# 315            0            0.000000          0.000000  26065004494                          0.000000                     0.000000                       0                        0.000000                      0.000000  42.725 -84.464               0.816193                              0.000000       0.437390         0.557029       0.000000            0.179452
# ...          ...                 ...               ...          ...                               ...                          ...                     ...                             ...                           ...     ...     ...                    ...                                   ...            ...              ...            ...                 ...
# 53             1            0.006173          6.199715   1015002600                          0.087005                     0.001302                       1                        0.027778                      6.199715  33.777 -86.041               0.943107                              0.000585       0.287424         0.098143       0.617321            0.062699
# 350            0            0.000000          0.000000  26065980300                          0.000000                     0.000000                       0                        0.000000                      0.000000  42.518 -84.321               0.816193                              0.000000       0.437390         0.557029       0.000000            0.179452
# 79             0            0.000000          0.000000   1015981903                          0.000000                     0.000000                       0                        0.000000                      0.000000  33.702 -85.755               0.936543                              0.000000       0.287424         0.098143       0.617321            0.062699
# 792            1            0.006173         13.033131  26125175100                         18.677684                     0.002446                       1                        0.027778                     13.033131  42.465 -83.098               0.803063                              0.000420       0.023864         0.766578       0.727090            0.502321
# 1544           0            0.000000          0.000000  26163583500                          0.000000                     0.000000                       0                        0.000000                      0.000000  42.245 -83.240               0.803063                              0.000000       0.220542         0.153846       0.170191            1.000000
#
# [1246 rows x 17 columns]

# %%
y_train=df_train.pop('solar_system_count_residential')
X_train=df_train

# %%
import statsmodels.api as sm
X_train_lm=sm.add_constant(X_train)

lr_1=sm.OLS(y_train, X_train_lm.astype(float)).fit()
lr_1.summary()
# Out:
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     solar_system_count_residential   R-squared:                       0.981
# Model:                                        OLS   Adj. R-squared:                  0.981
# Method:                             Least Squares   F-statistic:                     3966.
# Date:                            Wed, 24 Aug 2022   Prob (F-statistic):               0.00
# Time:                                    02:43:58   Log-Likelihood:                 3680.0
# No. Observations:                            1246   AIC:                            -7326.
# Df Residuals:                                1229   BIC:                            -7239.
# Df Model:                                      16
# Covariance Type:                        nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# const                                   -0.0034      0.003     -1.092      0.275      -0.010       0.003
# tile_count                              -0.0006      0.000     -4.398      0.000      -0.001      -0.000
# solar_system_count                       0.3480      0.040      8.804      0.000       0.270       0.426
# total_panel_area                      1.176e-06    9.5e-07      1.237      0.216   -6.89e-07    3.04e-06
# fips                                  2.176e-13   6.17e-14      3.529      0.000    9.66e-14    3.39e-13
# solar_panel_area_divided_by_area      3.193e-05   5.18e-06      6.169      0.000    2.18e-05    4.21e-05
# solar_panel_area_per_capita              0.0013      0.001      0.976      0.329      -0.001       0.004
# tile_count_residential                   0.0222      0.000     53.184      0.000       0.021       0.023
# total_panel_area_residential          -7.18e-05    1.7e-05     -4.216      0.000      -0.000   -3.84e-05
# lat                                     -0.0007      0.000     -4.599      0.000      -0.001      -0.000
# lon                                     -0.0008      0.000     -5.092      0.000      -0.001      -0.000
# daily_solar_radiation                   -0.0395      0.010     -3.827      0.000      -0.060      -0.019
# number_of_solar_system_per_household    -0.0146      0.026     -0.557      0.578      -0.066       0.037
# median_income                           -0.0012      0.002     -0.574      0.566      -0.005       0.003
# education_level                          0.0015      0.002      0.968      0.333      -0.001       0.004
# homeownership                            0.0019      0.002      0.832      0.406      -0.003       0.007
# population_density                   -4.601e-05      0.002     -0.026      0.980      -0.004       0.003
# ==============================================================================
# Omnibus:                      243.952   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5801.072
# Skew:                           0.195   Prob(JB):                         0.00
# Kurtosis:                      13.563   Cond. No.                     3.00e+12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  3e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['Features']=X_train.columns
vif['VIF']=[variance_inflation_factor((X_train.values).astype(float), i).astype(float) for i in range(X_train.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by="VIF", ascending=False)
vif
# Out:
#                                 Features      VIF
# 9                                    lon  1026.09
# 10                 daily_solar_radiation   511.19
# 8                                    lat   288.29
# 0                             tile_count    73.48
# 2                       total_panel_area    49.86
# 6                 tile_count_residential    30.48
# 7           total_panel_area_residential    24.58
# 1                     solar_system_count    20.66
# 3                                   fips    16.06
# 15                    population_density     8.30
# 11  number_of_solar_system_per_household     7.64
# 5            solar_panel_area_per_capita     7.60
# 14                         homeownership     5.80
# 13                       education_level     3.77
# 12                         median_income     3.62
# 4       solar_panel_area_divided_by_area     1.44

# %%
X=X_train.drop('lon', 1,)
X_train_lm=sm.add_constant(X)

lr_2=sm.OLS(y_train, X_train_lm.astype(float)).fit()

print(lr_2.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     solar_system_count_residential   R-squared:                       0.981
# Model:                                        OLS   Adj. R-squared:                  0.980
# Method:                             Least Squares   F-statistic:                     4144.
# Date:                            Wed, 24 Aug 2022   Prob (F-statistic):               0.00
# Time:                                    02:43:59   Log-Likelihood:                 3667.0
# No. Observations:                            1246   AIC:                            -7302.
# Df Residuals:                                1230   BIC:                            -7220.
# Df Model:                                      15
# Covariance Type:                        nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# const                                    0.0010      0.003      0.315      0.753      -0.005       0.007
# tile_count                              -0.0006      0.000     -4.555      0.000      -0.001      -0.000
# solar_system_count                       0.3736      0.040      9.433      0.000       0.296       0.451
# total_panel_area                      1.147e-06    9.6e-07      1.195      0.232   -7.37e-07    3.03e-06
# fips                                  1.275e-13   5.97e-14      2.136      0.033    1.04e-14    2.45e-13
# solar_panel_area_divided_by_area      3.355e-05   5.22e-06      6.429      0.000    2.33e-05    4.38e-05
# solar_panel_area_per_capita              0.0010      0.001      0.785      0.432      -0.002       0.004
# tile_count_residential                   0.0219      0.000     52.506      0.000       0.021       0.023
# total_panel_area_residential         -6.909e-05   1.72e-05     -4.019      0.000      -0.000   -3.54e-05
# lat                                     -0.0001      0.000     -1.079      0.281      -0.000    8.96e-05
# daily_solar_radiation                    0.0060      0.005      1.152      0.250      -0.004       0.016
# number_of_solar_system_per_household    -0.0093      0.026     -0.353      0.724      -0.061       0.043
# median_income                           -0.0028      0.002     -1.352      0.177      -0.007       0.001
# education_level                          0.0020      0.002      1.290      0.197      -0.001       0.005
# homeownership                            0.0005      0.002      0.223      0.824      -0.004       0.005
# population_density                      -0.0010      0.002     -0.570      0.569      -0.005       0.003
# ==============================================================================
# Omnibus:                      253.815   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6129.827
# Skew:                           0.264   Prob(JB):                         0.00
# Kurtosis:                      13.853   Cond. No.                     2.98e+12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.98e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /var/folders/n0/yz95y58n75741ysmfhkgrk_00000gn/T/ipykernel_36077/3729629882.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X=X_train.drop('lon', 1,)
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
vif=pd.DataFrame()
vif['Features']=X.columns
vif['VIF']=[variance_inflation_factor((X.values).astype(float), i).astype(float) for i in range(X.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by="VIF", ascending=False)
vif
# Out:
#                                 Features     VIF
# 8                                    lat  127.74
# 9                  daily_solar_radiation  119.29
# 0                             tile_count   73.36
# 2                       total_panel_area   49.86
# 6                 tile_count_residential   29.69
# 7           total_panel_area_residential   24.56
# 1                     solar_system_count   20.28
# 3                                   fips   15.56
# 14                    population_density    8.27
# 10  number_of_solar_system_per_household    7.64
# 5            solar_panel_area_per_capita    7.59
# 13                         homeownership    5.78
# 12                       education_level    3.74
# 11                         median_income    3.62
# 4       solar_panel_area_divided_by_area    1.44

# %%
X=X.drop('lat', 1)
X_train_lm=sm.add_constant(X)
lr_3=sm.OLS(y_train, X_train_lm.astype(float)).fit()

print(lr_3.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     solar_system_count_residential   R-squared:                       0.981
# Model:                                        OLS   Adj. R-squared:                  0.980
# Method:                             Least Squares   F-statistic:                     4440.
# Date:                            Wed, 24 Aug 2022   Prob (F-statistic):               0.00
# Time:                                    02:43:59   Log-Likelihood:                 3666.4
# No. Observations:                            1246   AIC:                            -7303.
# Df Residuals:                                1231   BIC:                            -7226.
# Df Model:                                      14
# Covariance Type:                        nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# const                                    0.0013      0.003      0.427      0.669      -0.005       0.007
# tile_count                              -0.0006      0.000     -4.605      0.000      -0.001      -0.000
# solar_system_count                       0.3716      0.040      9.392      0.000       0.294       0.449
# total_panel_area                       1.22e-06   9.58e-07      1.274      0.203   -6.59e-07     3.1e-06
# fips                                   1.18e-13    5.9e-14      1.999      0.046    2.21e-15    2.34e-13
# solar_panel_area_divided_by_area      3.317e-05   5.21e-06      6.370      0.000     2.3e-05    4.34e-05
# solar_panel_area_per_capita              0.0011      0.001      0.837      0.403      -0.001       0.004
# tile_count_residential                   0.0219      0.000     52.492      0.000       0.021       0.023
# total_panel_area_residential         -6.769e-05   1.71e-05     -3.948      0.000      -0.000   -3.41e-05
# daily_solar_radiation                    0.0008      0.002      0.404      0.687      -0.003       0.005
# number_of_solar_system_per_household    -0.0101      0.026     -0.380      0.704      -0.062       0.042
# median_income                           -0.0028      0.002     -1.365      0.172      -0.007       0.001
# education_level                          0.0016      0.001      1.063      0.288      -0.001       0.004
# homeownership                            0.0004      0.002      0.177      0.860      -0.004       0.005
# population_density                      -0.0013      0.002     -0.747      0.455      -0.005       0.002
# ==============================================================================
# Omnibus:                      257.020   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6303.394
# Skew:                           0.277   Prob(JB):                         0.00
# Kurtosis:                      14.005   Cond. No.                     2.97e+12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.97e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /var/folders/n0/yz95y58n75741ysmfhkgrk_00000gn/T/ipykernel_36077/1499687071.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X=X.drop('lat', 1)
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
vif=pd.DataFrame()
vif['Features']=X.columns
vif['VIF']=[variance_inflation_factor((X.values).astype(float), i).astype(float) for i in range(X.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by="VIF", ascending=False)
vif
# Out:
#                                 Features    VIF
# 0                             tile_count  73.22
# 2                       total_panel_area  49.61
# 6                 tile_count_residential  29.68
# 7           total_panel_area_residential  24.41
# 1                     solar_system_count  20.24
# 3                                   fips  15.37
# 8                  daily_solar_radiation  12.89
# 13                    population_density   8.15
# 9   number_of_solar_system_per_household   7.63
# 5            solar_panel_area_per_capita   7.57
# 12                         homeownership   5.77
# 10                         median_income   3.62
# 11                       education_level   3.54
# 4       solar_panel_area_divided_by_area   1.43

# %%
X=X.drop('tile_count', 1)
X_train_lm=sm.add_constant(X)
lr_4=sm.OLS(y_train, X_train_lm.astype(float)).fit()

print(lr_4.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     solar_system_count_residential   R-squared:                       0.980
# Model:                                        OLS   Adj. R-squared:                  0.980
# Method:                             Least Squares   F-statistic:                     4702.
# Date:                            Wed, 24 Aug 2022   Prob (F-statistic):               0.00
# Time:                                    02:43:59   Log-Likelihood:                 3655.8
# No. Observations:                            1246   AIC:                            -7284.
# Df Residuals:                                1232   BIC:                            -7212.
# Df Model:                                      13
# Covariance Type:                        nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# const                                    0.0015      0.003      0.496      0.620      -0.004       0.008
# solar_system_count                       0.2872      0.035      8.124      0.000       0.218       0.357
# total_panel_area                     -2.961e-06   3.07e-07     -9.653      0.000   -3.56e-06   -2.36e-06
# fips                                  1.179e-13   5.95e-14      1.982      0.048     1.2e-15    2.35e-13
# solar_panel_area_divided_by_area      3.435e-05   5.24e-06      6.550      0.000    2.41e-05    4.46e-05
# solar_panel_area_per_capita              0.0011      0.001      0.844      0.399      -0.001       0.004
# tile_count_residential                   0.0218      0.000     51.914      0.000       0.021       0.023
# total_panel_area_residential         -7.028e-05   1.73e-05     -4.069      0.000      -0.000   -3.64e-05
# daily_solar_radiation                    0.0007      0.002      0.377      0.706      -0.003       0.005
# number_of_solar_system_per_household    -0.0101      0.027     -0.378      0.706      -0.062       0.042
# median_income                           -0.0028      0.002     -1.334      0.182      -0.007       0.001
# education_level                          0.0014      0.001      0.978      0.328      -0.001       0.004
# homeownership                            0.0004      0.002      0.189      0.850      -0.004       0.005
# population_density                      -0.0015      0.002     -0.808      0.419      -0.005       0.002
# ==============================================================================
# Omnibus:                      210.338   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3837.259
# Skew:                           0.063   Prob(JB):                         0.00
# Kurtosis:                      11.596   Cond. No.                     2.64e+12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.64e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /var/folders/n0/yz95y58n75741ysmfhkgrk_00000gn/T/ipykernel_36077/1118379687.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X=X.drop('tile_count', 1)
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
vif=pd.DataFrame()
vif['Features']=X.columns
vif['VIF']=[variance_inflation_factor((X.values).astype(float), i).astype(float) for i in range(X.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by="VIF", ascending=False)
vif
# Out:
#                                 Features    VIF
# 5                 tile_count_residential  29.62
# 6           total_panel_area_residential  24.38
# 0                     solar_system_count  15.90
# 2                                   fips  15.37
# 7                  daily_solar_radiation  12.89
# 12                    population_density   8.15
# 8   number_of_solar_system_per_household   7.63
# 4            solar_panel_area_per_capita   7.57
# 11                         homeownership   5.77
# 1                       total_panel_area   5.00
# 9                          median_income   3.61
# 10                       education_level   3.54
# 3       solar_panel_area_divided_by_area   1.43

# %%
X=X.drop('tile_count_residential', 1)
X_train_lm=sm.add_constant(X)
lr_5=sm.OLS(y_train, X_train_lm.astype(float)).fit()

print(lr_5.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     solar_system_count_residential   R-squared:                       0.937
# Model:                                        OLS   Adj. R-squared:                  0.936
# Method:                             Least Squares   F-statistic:                     1529.
# Date:                            Wed, 24 Aug 2022   Prob (F-statistic):               0.00
# Time:                                    02:44:00   Log-Likelihood:                 2933.6
# No. Observations:                            1246   AIC:                            -5841.
# Df Residuals:                                1233   BIC:                            -5775.
# Df Model:                                      12
# Covariance Type:                        nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# const                                   -0.0058      0.005     -1.053      0.293      -0.016       0.005
# solar_system_count                       1.0385      0.058     18.040      0.000       0.926       1.151
# total_panel_area                     -9.442e-06      5e-07    -18.879      0.000   -1.04e-05   -8.46e-06
# fips                                  5.272e-13   1.05e-13      5.008      0.000    3.21e-13    7.34e-13
# solar_panel_area_divided_by_area      2.921e-05   9.36e-06      3.122      0.002    1.09e-05    4.76e-05
# solar_panel_area_per_capita             -0.0028      0.002     -1.206      0.228      -0.007       0.002
# total_panel_area_residential             0.0007   1.71e-05     39.694      0.000       0.001       0.001
# daily_solar_radiation                   -0.0019      0.003     -0.539      0.590      -0.009       0.005
# number_of_solar_system_per_household     0.0787      0.048      1.654      0.098      -0.015       0.172
# median_income                           -0.0022      0.004     -0.610      0.542      -0.009       0.005
# education_level                          0.0071      0.003      2.682      0.007       0.002       0.012
# homeownership                            0.0050      0.004      1.192      0.233      -0.003       0.013
# population_density                      -0.0005      0.003     -0.162      0.872      -0.007       0.006
# ==============================================================================
# Omnibus:                      551.240   Durbin-Watson:                   1.948
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13592.871
# Skew:                           1.487   Prob(JB):                         0.00
# Kurtosis:                      18.905   Cond. No.                     2.41e+12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.41e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /var/folders/n0/yz95y58n75741ysmfhkgrk_00000gn/T/ipykernel_36077/3507106713.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X=X.drop('tile_count_residential', 1)
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
vif=pd.DataFrame()
vif['Features']=X.columns
vif['VIF']=[variance_inflation_factor((X.values).astype(float), i).astype(float) for i in range(X.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by="VIF", ascending=False)
vif
# Out:
#                                 Features    VIF
# 2                                   fips  15.12
# 0                     solar_system_count  13.25
# 6                  daily_solar_radiation  12.84
# 11                    population_density   8.14
# 7   number_of_solar_system_per_household   7.60
# 4            solar_panel_area_per_capita   7.54
# 5           total_panel_area_residential   7.45
# 10                         homeownership   5.77
# 1                       total_panel_area   4.18
# 8                          median_income   3.61
# 9                        education_level   3.52
# 3       solar_panel_area_divided_by_area   1.43

# %%
X=X.drop('fips', 1)
X_train_lm=sm.add_constant(X)
lr_6=sm.OLS(y_train, X_train_lm.astype(float)).fit()

print(lr_6.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     solar_system_count_residential   R-squared:                       0.936
# Model:                                        OLS   Adj. R-squared:                  0.935
# Method:                             Least Squares   F-statistic:                     1634.
# Date:                            Wed, 24 Aug 2022   Prob (F-statistic):               0.00
# Time:                                    02:44:00   Log-Likelihood:                 2921.0
# No. Observations:                            1246   AIC:                            -5818.
# Df Residuals:                                1234   BIC:                            -5757.
# Df Model:                                      11
# Covariance Type:                        nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# const                                    0.0070      0.005      1.438      0.151      -0.003       0.017
# solar_system_count                       1.0400      0.058     17.892      0.000       0.926       1.154
# total_panel_area                      -9.44e-06   5.05e-07    -18.694      0.000   -1.04e-05   -8.45e-06
# solar_panel_area_divided_by_area      3.108e-05   9.44e-06      3.293      0.001    1.26e-05    4.96e-05
# solar_panel_area_per_capita             -0.0036      0.002     -1.526      0.127      -0.008       0.001
# total_panel_area_residential             0.0007   1.72e-05     39.059      0.000       0.001       0.001
# daily_solar_radiation                   -0.0040      0.003     -1.176      0.240      -0.011       0.003
# number_of_solar_system_per_household     0.0874      0.048      1.820      0.069      -0.007       0.182
# median_income                           -0.0004      0.004     -0.096      0.924      -0.008       0.007
# education_level                          0.0079      0.003      2.992      0.003       0.003       0.013
# homeownership                            0.0060      0.004      1.403      0.161      -0.002       0.014
# population_density                       0.0025      0.003      0.795      0.427      -0.004       0.009
# ==============================================================================
# Omnibus:                      572.579   Durbin-Watson:                   1.938
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15238.692
# Skew:                           1.548   Prob(JB):                         0.00
# Kurtosis:                      19.851   Cond. No.                     2.35e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.35e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /var/folders/n0/yz95y58n75741ysmfhkgrk_00000gn/T/ipykernel_36077/3417860792.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X=X.drop('fips', 1)
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
vif=pd.DataFrame()
vif['Features']=X.columns
vif['VIF']=[variance_inflation_factor((X.values).astype(float), i).astype(float) for i in range(X.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by="VIF", ascending=False)
vif
# Out:
#                                 Features    VIF
# 0                     solar_system_count  13.25
# 5                  daily_solar_radiation  12.58
# 6   number_of_solar_system_per_household   7.59
# 3            solar_panel_area_per_capita   7.53
# 4           total_panel_area_residential   7.38
# 10                    population_density   4.90
# 9                          homeownership   4.57
# 1                       total_panel_area   4.17
# 8                        education_level   3.48
# 7                          median_income   2.77
# 2       solar_panel_area_divided_by_area   1.42

# %%
X=X.drop('solar_system_count', 1)
X_train_lm=sm.add_constant(X)
lr_7=sm.OLS(y_train, X_train_lm.astype(float)).fit()

print(lr_7.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     solar_system_count_residential   R-squared:                       0.919
# Model:                                        OLS   Adj. R-squared:                  0.918
# Method:                             Least Squares   F-statistic:                     1403.
# Date:                            Wed, 24 Aug 2022   Prob (F-statistic):               0.00
# Time:                                    02:44:01   Log-Likelihood:                 2777.3
# No. Observations:                            1246   AIC:                            -5533.
# Df Residuals:                                1235   BIC:                            -5476.
# Df Model:                                      10
# Covariance Type:                        nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# const                                    0.0102      0.005      1.859      0.063      -0.001       0.021
# total_panel_area                     -1.796e-06   3.02e-07     -5.946      0.000   -2.39e-06    -1.2e-06
# solar_panel_area_divided_by_area      2.567e-05   1.06e-05      2.426      0.015    4.91e-06    4.64e-05
# solar_panel_area_per_capita             -0.0044      0.003     -1.667      0.096      -0.010       0.001
# total_panel_area_residential             0.0009   9.67e-06     96.839      0.000       0.001       0.001
# daily_solar_radiation                   -0.0066      0.004     -1.717      0.086      -0.014       0.001
# number_of_solar_system_per_household     0.1004      0.054      1.865      0.062      -0.005       0.206
# median_income                            0.0007      0.004      0.171      0.864      -0.007       0.009
# education_level                          0.0091      0.003      3.066      0.002       0.003       0.015
# homeownership                            0.0088      0.005      1.853      0.064      -0.001       0.018
# population_density                       0.0024      0.004      0.678      0.498      -0.005       0.009
# ==============================================================================
# Omnibus:                      255.806   Durbin-Watson:                   1.928
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2295.674
# Skew:                           0.680   Prob(JB):                         0.00
# Kurtosis:                       9.509   Cond. No.                     1.95e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.95e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /var/folders/n0/yz95y58n75741ysmfhkgrk_00000gn/T/ipykernel_36077/2587148026.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X=X.drop('solar_system_count', 1)
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
vif=pd.DataFrame()
vif['Features']=X.columns
vif['VIF']=[variance_inflation_factor((X.values).astype(float), i).astype(float) for i in range(X.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by="VIF", ascending=False)
vif
# Out:
#                                Features    VIF
# 4                 daily_solar_radiation  12.57
# 5  number_of_solar_system_per_household   7.59
# 2           solar_panel_area_per_capita   7.52
# 9                    population_density   4.90
# 8                         homeownership   4.54
# 7                       education_level   3.48
# 6                         median_income   2.76
# 3          total_panel_area_residential   1.85
# 1      solar_panel_area_divided_by_area   1.42
# 0                      total_panel_area   1.19

# %%
X=X.drop('daily_solar_radiation', 1)
X_train_lm=sm.add_constant(X)
lr_8=sm.OLS(y_train, X_train_lm.astype(float)).fit()

print(lr_8.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     solar_system_count_residential   R-squared:                       0.919
# Model:                                        OLS   Adj. R-squared:                  0.918
# Method:                             Least Squares   F-statistic:                     1556.
# Date:                            Wed, 24 Aug 2022   Prob (F-statistic):               0.00
# Time:                                    02:44:01   Log-Likelihood:                 2775.8
# No. Observations:                            1246   AIC:                            -5532.
# Df Residuals:                                1236   BIC:                            -5480.
# Df Model:                                       9
# Covariance Type:                        nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# const                                    0.0054      0.005      1.144      0.253      -0.004       0.015
# total_panel_area                      -1.81e-06   3.02e-07     -5.993      0.000    -2.4e-06   -1.22e-06
# solar_panel_area_divided_by_area      2.501e-05   1.06e-05      2.363      0.018    4.25e-06    4.58e-05
# solar_panel_area_per_capita             -0.0045      0.003     -1.685      0.092      -0.010       0.001
# total_panel_area_residential             0.0009   9.68e-06     96.751      0.000       0.001       0.001
# number_of_solar_system_per_household     0.1004      0.054      1.863      0.063      -0.005       0.206
# median_income                            0.0010      0.004      0.238      0.812      -0.007       0.009
# education_level                          0.0090      0.003      3.028      0.003       0.003       0.015
# homeownership                            0.0087      0.005      1.832      0.067      -0.001       0.018
# population_density                       0.0020      0.004      0.554      0.580      -0.005       0.009
# ==============================================================================
# Omnibus:                      256.361   Durbin-Watson:                   1.932
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2308.273
# Skew:                           0.681   Prob(JB):                         0.00
# Kurtosis:                       9.527   Cond. No.                     1.95e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.95e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /var/folders/n0/yz95y58n75741ysmfhkgrk_00000gn/T/ipykernel_36077/1668260529.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X=X.drop('daily_solar_radiation', 1)
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
vif=pd.DataFrame()
vif['Features']=X.columns
vif['VIF']=[variance_inflation_factor((X.values).astype(float), i).astype(float) for i in range(X.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by="VIF", ascending=False)
vif
# Out:
#                                Features   VIF
# 4  number_of_solar_system_per_household  7.59
# 2           solar_panel_area_per_capita  7.52
# 6                       education_level  3.46
# 7                         homeownership  2.90
# 5                         median_income  2.11
# 3          total_panel_area_residential  1.85
# 8                    population_density  1.53
# 1      solar_panel_area_divided_by_area  1.42
# 0                      total_panel_area  1.19

# %%
X=X.drop('number_of_solar_system_per_household', 1)
X_train_lm=sm.add_constant(X)
lr_9=sm.OLS(y_train, X_train_lm.astype(float)).fit()

print(lr_9.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     solar_system_count_residential   R-squared:                       0.919
# Model:                                        OLS   Adj. R-squared:                  0.918
# Method:                             Least Squares   F-statistic:                     1746.
# Date:                            Wed, 24 Aug 2022   Prob (F-statistic):               0.00
# Time:                                    02:44:02   Log-Likelihood:                 2774.1
# No. Observations:                            1246   AIC:                            -5530.
# Df Residuals:                                1237   BIC:                            -5484.
# Df Model:                                       8
# Covariance Type:                        nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                                0.0053      0.005      1.115      0.265      -0.004       0.015
# total_panel_area                 -1.813e-06   3.02e-07     -5.997      0.000   -2.41e-06   -1.22e-06
# solar_panel_area_divided_by_area  2.535e-05   1.06e-05      2.393      0.017    4.56e-06    4.61e-05
# solar_panel_area_per_capita          0.0001      0.001      0.131      0.896      -0.002       0.002
# total_panel_area_residential         0.0009   9.67e-06     96.931      0.000       0.001       0.001
# median_income                        0.0013      0.004      0.310      0.757      -0.007       0.009
# education_level                      0.0095      0.003      3.188      0.001       0.004       0.015
# homeownership                        0.0085      0.005      1.774      0.076      -0.001       0.018
# population_density                   0.0020      0.004      0.572      0.567      -0.005       0.009
# ==============================================================================
# Omnibus:                      255.545   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2328.305
# Skew:                           0.674   Prob(JB):                         0.00
# Kurtosis:                       9.560   Cond. No.                     2.83e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.83e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /var/folders/n0/yz95y58n75741ysmfhkgrk_00000gn/T/ipykernel_36077/1942376893.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X=X.drop('number_of_solar_system_per_household', 1)
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
vif=pd.DataFrame()
vif['Features']=X.columns
vif['VIF']=[variance_inflation_factor((X.values).astype(float), i).astype(float) for i in range(X.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by="VIF", ascending=False)
vif
# Out:
#                            Features   VIF
# 5                   education_level  3.44
# 6                     homeownership  2.88
# 4                     median_income  2.11
# 3      total_panel_area_residential  1.84
# 7                population_density  1.53
# 1  solar_panel_area_divided_by_area  1.42
# 0                  total_panel_area  1.19
# 2       solar_panel_area_per_capita  1.01

# %%
X=X.drop('solar_panel_area_per_capita', 1)
X_train_lm=sm.add_constant(X)
lr_10=sm.OLS(y_train, X_train_lm.astype(float)).fit()

print(lr_10.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     solar_system_count_residential   R-squared:                       0.919
# Model:                                        OLS   Adj. R-squared:                  0.918
# Method:                             Least Squares   F-statistic:                     1997.
# Date:                            Wed, 24 Aug 2022   Prob (F-statistic):               0.00
# Time:                                    02:44:02   Log-Likelihood:                 2774.1
# No. Observations:                            1246   AIC:                            -5532.
# Df Residuals:                                1238   BIC:                            -5491.
# Df Model:                                       7
# Covariance Type:                        nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                                0.0053      0.005      1.122      0.262      -0.004       0.015
# total_panel_area                 -1.814e-06   3.02e-07     -6.000      0.000   -2.41e-06   -1.22e-06
# solar_panel_area_divided_by_area  2.534e-05   1.06e-05      2.393      0.017    4.57e-06    4.61e-05
# total_panel_area_residential         0.0009   9.65e-06     97.103      0.000       0.001       0.001
# median_income                        0.0013      0.004      0.308      0.758      -0.007       0.009
# education_level                      0.0095      0.003      3.187      0.001       0.004       0.015
# homeownership                        0.0085      0.005      1.772      0.077      -0.001       0.018
# population_density                   0.0020      0.004      0.566      0.571      -0.005       0.009
# ==============================================================================
# Omnibus:                      255.343   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2329.246
# Skew:                           0.673   Prob(JB):                         0.00
# Kurtosis:                       9.561   Cond. No.                     2.83e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.83e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /var/folders/n0/yz95y58n75741ysmfhkgrk_00000gn/T/ipykernel_36077/3731976518.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X=X.drop('solar_panel_area_per_capita', 1)
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
vif=pd.DataFrame()
vif['Features']=X.columns
vif['VIF']=[variance_inflation_factor((X.values).astype(float), i).astype(float) for i in range(X.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by="VIF", ascending=False)
vif
# Out:
#                            Features   VIF
# 4                   education_level  3.43
# 5                     homeownership  2.88
# 3                     median_income  2.10
# 2      total_panel_area_residential  1.84
# 6                population_density  1.53
# 1  solar_panel_area_divided_by_area  1.42
# 0                  total_panel_area  1.19

# %%
X=X.drop('median_income', 1)
X_train_lm=sm.add_constant(X)
lr_11=sm.OLS(y_train, X_train_lm.astype(float)).fit()

print(lr_11.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     solar_system_count_residential   R-squared:                       0.919
# Model:                                        OLS   Adj. R-squared:                  0.918
# Method:                             Least Squares   F-statistic:                     2332.
# Date:                            Wed, 24 Aug 2022   Prob (F-statistic):               0.00
# Time:                                    02:44:02   Log-Likelihood:                 2774.0
# No. Observations:                            1246   AIC:                            -5534.
# Df Residuals:                                1239   BIC:                            -5498.
# Df Model:                                       6
# Covariance Type:                        nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                                0.0064      0.003      2.112      0.035       0.000       0.012
# total_panel_area                 -1.815e-06   3.02e-07     -6.006      0.000   -2.41e-06   -1.22e-06
# solar_panel_area_divided_by_area  2.541e-05   1.06e-05      2.401      0.016    4.65e-06    4.62e-05
# total_panel_area_residential         0.0009   9.45e-06     99.249      0.000       0.001       0.001
# education_level                      0.0096      0.003      3.275      0.001       0.004       0.015
# homeownership                        0.0075      0.004      2.028      0.043       0.000       0.015
# population_density                   0.0013      0.003      0.485      0.628      -0.004       0.006
# ==============================================================================
# Omnibus:                      255.442   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2338.290
# Skew:                           0.672   Prob(JB):                         0.00
# Kurtosis:                       9.575   Cond. No.                     1.76e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.76e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /var/folders/n0/yz95y58n75741ysmfhkgrk_00000gn/T/ipykernel_36077/4253414616.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X=X.drop('median_income', 1)
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
vif=pd.DataFrame()
vif['Features']=X.columns
vif['VIF']=[variance_inflation_factor((X.values).astype(float), i).astype(float) for i in range(X.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by="VIF", ascending=False)
vif
# Out:
#                            Features   VIF
# 3                   education_level  2.91
# 4                     homeownership  2.88
# 2      total_panel_area_residential  1.77
# 5                population_density  1.47
# 1  solar_panel_area_divided_by_area  1.42
# 0                  total_panel_area  1.19

# %%
X=X.drop('population_density', 1)
X_train_lm=sm.add_constant(X)
lr_12=sm.OLS(y_train, X_train_lm.astype(float)).fit()

print(lr_12.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     solar_system_count_residential   R-squared:                       0.919
# Model:                                        OLS   Adj. R-squared:                  0.918
# Method:                             Least Squares   F-statistic:                     2800.
# Date:                            Wed, 24 Aug 2022   Prob (F-statistic):               0.00
# Time:                                    02:44:03   Log-Likelihood:                 2773.9
# No. Observations:                            1246   AIC:                            -5536.
# Df Residuals:                                1240   BIC:                            -5505.
# Df Model:                                       5
# Covariance Type:                        nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                                0.0077      0.001      5.295      0.000       0.005       0.011
# total_panel_area                 -1.812e-06   3.02e-07     -6.000      0.000    -2.4e-06   -1.22e-06
# solar_panel_area_divided_by_area  2.549e-05   1.06e-05      2.409      0.016    4.73e-06    4.62e-05
# total_panel_area_residential         0.0009   9.43e-06     99.435      0.000       0.001       0.001
# education_level                      0.0092      0.003      3.266      0.001       0.004       0.015
# homeownership                        0.0066      0.003      2.079      0.038       0.000       0.013
# ==============================================================================
# Omnibus:                      255.350   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2331.295
# Skew:                           0.673   Prob(JB):                         0.00
# Kurtosis:                       9.565   Cond. No.                     1.30e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.3e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /var/folders/n0/yz95y58n75741ysmfhkgrk_00000gn/T/ipykernel_36077/2989970046.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X=X.drop('population_density', 1)
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
vif=pd.DataFrame()
vif['Features']=X.columns
vif['VIF']=[variance_inflation_factor((X.values).astype(float), i).astype(float) for i in range(X.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by="VIF", ascending=False)
vif
# Out:
#                            Features   VIF
# 3                   education_level  2.84
# 4                     homeownership  2.72
# 2      total_panel_area_residential  1.77
# 1  solar_panel_area_divided_by_area  1.40
# 0                  total_panel_area  1.19

# %%
import seaborn as sns
y_train_solar_system_count_residential=lr_12.predict(X_train_lm)
fig=plt.figure()
sns.distplot((y_train-y_train_solar_system_count_residential),bins=20)
fig.suptitle('Error Terms', fontsize=20)
plt.xlabel('Errors', fontsize=18)
# Out:
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Errors')

# %%
numerical_variables=['daily_solar_radiation','median_income', 'education_level', 'homeownership','population_density', 'solar_system_count_residential', 'number_of_solar_system_per_household', 'solar_system_count']
df_test[numerical_variables]=scaler.transform(df_test[numerical_variables])
df_test
# Out:
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
#       tile_count  solar_system_count  total_panel_area         fips  solar_panel_area_divided_by_area  solar_panel_area_per_capita  tile_count_residential  solar_system_count_residential  total_panel_area_residential     lat     lon  daily_solar_radiation  number_of_solar_system_per_household  median_income  education_level  homeownership  population_density
# 779            7            0.043210        115.061710  26125152600                        114.782101                     0.029863                       7                        0.194444                    115.061710  42.553 -83.227               0.803063                              0.004548       0.023864         0.766578       0.727090            0.502321
# 890            4            0.024691        364.083059  26125121400                         12.963026                     0.024932                       2                        0.055556                    109.477788  42.854 -83.303               0.803063                              0.001336       0.023864         0.766578       0.727090            0.502321
# 1086           3            0.018519         37.416821  26163568000                         37.511105                     0.016938                       3                        0.083333                     37.416821  42.317 -83.399               0.803063                              0.002688       0.220542         0.153846       0.170191            1.000000
# 1751           1            0.006173         57.031051  37191000601                          8.206342                     0.012281                       1                        0.027778                     57.031051  35.310 -78.012               0.927790                              0.000609       0.220542         0.153846       0.170191            1.000000
# 592            4            0.024691         91.211065  26125142400                         96.630223                     0.029480                       4                        0.111111                     91.211065  42.627 -83.281               0.803063                              0.003152       0.023864         0.766578       0.727090            0.502321
# ...          ...                 ...               ...          ...                               ...                          ...                     ...                             ...                           ...     ...     ...                    ...                                   ...            ...              ...            ...                 ...
# 1648           0            0.000000          0.000000  42127960300                          0.000000                     0.000000                       0                        0.000000                      0.000000  41.634 -75.386               0.789934                              0.000000       0.220542         0.153846       0.170191            1.000000
# 1065           0            0.000000          0.000000  26163518600                          0.000000                     0.000000                       0                        0.000000                      0.000000  42.364 -83.030               0.803063                              0.000000       0.220542         0.153846       0.170191            1.000000
# 1634           0            0.000000          0.000000  26163553300                          0.000000                     0.000000                       0                        0.000000                      0.000000  42.397 -83.106               0.803063                              0.000000       0.220542         0.153846       0.170191            1.000000
# 1575           4            0.006173        207.444845  26163536100                          0.000000                     0.000000                       0                        0.000000                      0.000000  42.413 -83.150               0.803063                              0.000000       0.220542         0.153846       0.170191            1.000000
# 935            2            0.012346         38.398887  26161403500                         68.369168                     0.014866                       2                        0.055556                     38.398887  42.279 -83.770               0.803063                              0.001483       1.000000         1.000000       0.197382            0.179088
#
# [534 rows x 17 columns]

# %%
y_test = df_test.pop('solar_system_count_residential')
X_test = df_test
X_test_m4=sm.add_constant(X_test)
X_test_m4 = X_test_m4.drop(['lon','lat','tile_count','tile_count_residential','fips','solar_system_count','daily_solar_radiation','number_of_solar_system_per_household','solar_panel_area_per_capita','median_income','population_density'], axis=1)
y_pred_m4=lr_12.predict(X_test_m4)
# Out:
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
from sklearn.metrics import r2_score
r2_score=r2_score(y_true=y_test, y_pred = y_pred_m4)
print("R-Squared Value: " + str(r2_score))
# Out:
# R-Squared Value: 0.929661012296137

# %%
from sklearn.metrics import mean_absolute_error as mae
error=mae(y_true=y_test,y_pred=y_pred_m4)
print("Mean Absolute Error : " + str(error))
# Out:
# Mean Absolute Error : 0.019702950098455466

# %%
from sklearn.metrics import mean_squared_error
error2=mean_squared_error(y_true=y_test, y_pred=y_pred_m4)
print("Mean Squared Error: " + str(error2))
# Out:
# Mean Squared Error: 0.0008856228995905903

# %%
from sklearn.metrics import mean_squared_error
root_mean_squared=mean_squared_error(y_true=y_test, y_pred=y_pred_m4, squared=False)
print("Root Mean Squared: " + str(root_mean_squared))
# Out:
# Root Mean Squared: 0.029759416990098955

# %%
x=dataFrame[['daily_solar_radiation','median_income', 'education_level', 'homeownership','population_density']]
y=dataFrame['number_of_solar_system_per_household']

# %%
regr=linear_model.LinearRegression()
regr.fit(x,y)
# Out:
# LinearRegression()

# %%
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  0.03732605525444592
# Coefficients:
#  [ 1.20391485e-03 -2.00092670e-08  7.72413629e-05 -5.02597135e-04
#  -8.52695593e-06]

# %%
x=sm.add_constant(x)
model=sm.OLS(y,x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                                      OLS Regression Results
# ================================================================================================
# Dep. Variable:     number_of_solar_system_per_household   R-squared:                       0.008
# Model:                                              OLS   Adj. R-squared:                  0.005
# Method:                                   Least Squares   F-statistic:                     2.764
# Date:                                  Wed, 24 Aug 2022   Prob (F-statistic):             0.0171
# Time:                                          03:39:54   Log-Likelihood:                 3464.0
# No. Observations:                                  1780   AIC:                            -6916.
# Df Residuals:                                      1774   BIC:                            -6883.
# Df Model:                                             5
# Covariance Type:                              nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.0373      0.025      1.521      0.128      -0.011       0.085
# daily_solar_radiation     0.0012      0.001      1.316      0.188      -0.001       0.003
# median_income         -2.001e-08    1.5e-07     -0.134      0.894   -3.14e-07    2.74e-07
# education_level        7.724e-05    8.5e-05      0.909      0.363   -8.94e-05       0.000
# homeownership            -0.0005      0.000     -1.937      0.053      -0.001    6.26e-06
# population_density    -8.527e-06   3.54e-06     -2.409      0.016   -1.55e-05   -1.58e-06
# ==============================================================================
# Omnibus:                     4351.157   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         31409187.448
# Skew:                          24.961   Prob(JB):                         0.00
# Kurtosis:                     651.847   Cond. No.                     1.49e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.49e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
x=dataFrame[['daily_solar_radiation', 'education_level', 'homeownership']]
y=dataFrame['number_of_solar_system_per_household']

# %%
regr=linear_model.LinearRegression()
regr.fit(x,y)
# Out:
# LinearRegression()

# %%
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  0.005824056277887867
# Coefficients:
#  [ 0.00079664  0.00014888 -0.00015054]

# %%
x=sm.add_constant(x)
model=sm.OLS(y,x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                                      OLS Regression Results
# ================================================================================================
# Dep. Variable:     number_of_solar_system_per_household   R-squared:                       0.002
# Model:                                              OLS   Adj. R-squared:                  0.001
# Method:                                   Least Squares   F-statistic:                     1.425
# Date:                                  Wed, 24 Aug 2022   Prob (F-statistic):              0.234
# Time:                                          03:39:55   Log-Likelihood:                 3459.3
# No. Observations:                                  1780   AIC:                            -6911.
# Df Residuals:                                      1776   BIC:                            -6889.
# Df Model:                                             3
# Covariance Type:                              nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.0058      0.012      0.497      0.620      -0.017       0.029
# daily_solar_radiation     0.0008      0.001      0.878      0.380      -0.001       0.003
# education_level           0.0001   7.99e-05      1.863      0.063   -7.84e-06       0.000
# homeownership            -0.0002      0.000     -0.867      0.386      -0.000       0.000
# ==============================================================================
# Omnibus:                     4363.060   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         31913909.622
# Skew:                          25.129   Prob(JB):                         0.00
# Kurtosis:                     657.044   Cond. No.                     1.08e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
x=dataFrame[['daily_solar_radiation','median_income', 'education_level', 'homeownership','population_density']]
y=dataFrame['solar_system_count']

# %%
regr=linear_model.LinearRegression()
regr.fit(x,y)
# Out:
# LinearRegression()

# %%
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  -28.971445736898968
# Coefficients:
#  [7.05667984e-02 2.15521112e-04 2.67673051e-02 2.71088255e-01
#  2.33478200e-03]

# %%
x=sm.add_constant(x)
model=sm.OLS(y,x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     solar_system_count   R-squared:                       0.063
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     24.04
# Date:                Wed, 24 Aug 2022   Prob (F-statistic):           1.82e-23
# Time:                        03:39:55   Log-Likelihood:                -5672.9
# No. Observations:                1780   AIC:                         1.136e+04
# Df Residuals:                    1774   BIC:                         1.139e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                   -28.9714      4.160     -6.965      0.000     -37.130     -20.813
# daily_solar_radiation     0.0706      0.155      0.455      0.649      -0.234       0.375
# median_income             0.0002   2.54e-05      8.489      0.000       0.000       0.000
# education_level           0.0268      0.014      1.858      0.063      -0.001       0.055
# homeownership             0.2711      0.044      6.163      0.000       0.185       0.357
# population_density        0.0023      0.001      3.891      0.000       0.001       0.004
# ==============================================================================
# Omnibus:                     3333.657   Durbin-Watson:                   1.442
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7159683.404
# Skew:                          13.502   Prob(JB):                         0.00
# Kurtosis:                     312.525   Cond. No.                     1.49e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.49e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
x=dataFrame[['daily_solar_radiation','median_income', 'education_level', 'homeownership','population_density']]
y=dataFrame['solar_system_count_residential']

# %%
regr=linear_model.LinearRegression()
regr.fit(x,y)
# Out:
# LinearRegression()

# %%
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  -18.328645968346574
# Coefficients:
#  [-4.83837313e-02  1.36390173e-04  3.35921119e-02  1.74497482e-01
#   1.46367504e-03]

# %%
x=sm.add_constant(x)
model=sm.OLS(y,x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     solar_system_count_residential   R-squared:                       0.095
# Model:                                        OLS   Adj. R-squared:                  0.093
# Method:                             Least Squares   F-statistic:                     37.42
# Date:                            Wed, 24 Aug 2022   Prob (F-statistic):           1.40e-36
# Time:                                    03:39:56   Log-Likelihood:                -4684.9
# No. Observations:                            1780   AIC:                             9382.
# Df Residuals:                                1774   BIC:                             9415.
# Df Model:                                       5
# Covariance Type:                        nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                   -18.3286      2.388     -7.676      0.000     -23.012     -13.646
# daily_solar_radiation    -0.0484      0.089     -0.543      0.587      -0.223       0.126
# median_income             0.0001   1.46e-05      9.359      0.000       0.000       0.000
# education_level           0.0336      0.008      4.062      0.000       0.017       0.050
# homeownership             0.1745      0.025      6.911      0.000       0.125       0.224
# population_density        0.0015      0.000      4.249      0.000       0.001       0.002
# ==============================================================================
# Omnibus:                     1783.896   Durbin-Watson:                   1.228
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           130474.155
# Skew:                           4.690   Prob(JB):                         0.00
# Kurtosis:                      43.880   Cond. No.                     1.49e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.49e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
x=dataFrame[['median_income', 'education_level', 'homeownership','population_density']]
y=dataFrame['solar_system_count_residential']

# %%
regr=linear_model.LinearRegression()
regr.fit(x,y)
# Out:
# LinearRegression()

# %%
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  -18.46521481069761
# Coefficients:
#  [1.36576459e-04 3.33960128e-02 1.74145733e-01 1.44609574e-03]

# %%
x=sm.add_constant(x)
model=sm.OLS(y,x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     solar_system_count_residential   R-squared:                       0.095
# Model:                                        OLS   Adj. R-squared:                  0.093
# Method:                             Least Squares   F-statistic:                     46.73
# Date:                            Wed, 24 Aug 2022   Prob (F-statistic):           2.21e-37
# Time:                                    03:39:57   Log-Likelihood:                -4685.0
# No. Observations:                            1780   AIC:                             9380.
# Df Residuals:                                1775   BIC:                             9407.
# Df Model:                                       4
# Covariance Type:                        nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                -18.4652      2.374     -7.778      0.000     -23.121     -13.809
# median_income          0.0001   1.46e-05      9.376      0.000       0.000       0.000
# education_level        0.0334      0.008      4.043      0.000       0.017       0.050
# homeownership          0.1741      0.025      6.900      0.000       0.125       0.224
# population_density     0.0014      0.000      4.217      0.000       0.001       0.002
# ==============================================================================
# Omnibus:                     1786.095   Durbin-Watson:                   1.228
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           131499.405
# Skew:                           4.697   Prob(JB):                         0.00
# Kurtosis:                      44.046   Cond. No.                     1.48e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.48e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
x=dataFrame[['median_income', 'education_level', 'homeownership','population_density']]
y=dataFrame['solar_panel_area_per_capita']

# %%
regr=linear_model.LinearRegression()
regr.fit(x,y)
# Out:
# LinearRegression()

# %%
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  0.2363385103497748
# Coefficients:
#  [ 6.56895183e-08 -1.02982611e-03 -1.61990264e-03 -9.63175245e-05]

# %%
x=sm.add_constant(x)
model=sm.OLS(y,x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     solar_panel_area_per_capita   R-squared:                       0.003
# Model:                                     OLS   Adj. R-squared:                  0.000
# Method:                          Least Squares   F-statistic:                     1.133
# Date:                         Wed, 24 Aug 2022   Prob (F-statistic):              0.339
# Time:                                 03:39:58   Log-Likelihood:                -1726.2
# No. Observations:                         1780   AIC:                             3462.
# Df Residuals:                             1775   BIC:                             3490.
# Df Model:                                    4
# Covariance Type:                     nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.2363      0.450      0.525      0.600      -0.647       1.120
# median_income       6.569e-08   2.76e-06      0.024      0.981   -5.35e-06    5.49e-06
# education_level       -0.0010      0.002     -0.657      0.511      -0.004       0.002
# homeownership         -0.0016      0.005     -0.338      0.735      -0.011       0.008
# population_density -9.632e-05   6.51e-05     -1.481      0.139      -0.000    3.13e-05
# ==============================================================================
# Omnibus:                     5061.947   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        142677192.852
# Skew:                          36.279   Prob(JB):                         0.00
# Kurtosis:                    1388.089   Cond. No.                     1.48e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.48e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/eleazarescalante/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
corr_matrix = dataFrame.corr()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_5dd97_row0_col0, #T_5dd97_row1_col1, #T_5dd97_row2_col2, #T_5dd97_row3_col3, #T_5dd97_row4_col4, #T_5dd97_row5_col5, #T_5dd97_row6_col6, #T_5dd97_row7_col7, #T_5dd97_row8_col8, #T_5dd97_row9_col9, #T_5dd97_row10_col10, #T_5dd97_row11_col11, #T_5dd97_row12_col12, #T_5dd97_row13_col13, #T_5dd97_row14_col14, #T_5dd97_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5dd97_row0_col1, #T_5dd97_row1_col6 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_5dd97_row0_col2, #T_5dd97_row2_col0, #T_5dd97_row8_col10, #T_5dd97_row10_col8 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_5dd97_row0_col3 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_5dd97_row0_col4, #T_5dd97_row3_col4, #T_5dd97_row4_col3, #T_5dd97_row10_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_5dd97_row0_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_5dd97_row0_col6, #T_5dd97_row1_col8, #T_5dd97_row7_col3, #T_5dd97_row8_col15 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_5dd97_row0_col7, #T_5dd97_row0_col9, #T_5dd97_row0_col10, #T_5dd97_row4_col10, #T_5dd97_row11_col10 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_5dd97_row0_col8, #T_5dd97_row13_col12 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_5dd97_row0_col11, #T_5dd97_row5_col4, #T_5dd97_row12_col15, #T_5dd97_row13_col11 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_5dd97_row0_col12 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_5dd97_row0_col13, #T_5dd97_row2_col5, #T_5dd97_row11_col13 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_5dd97_row0_col14, #T_5dd97_row9_col14 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_5dd97_row0_col15, #T_5dd97_row3_col15, #T_5dd97_row11_col12 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_5dd97_row1_col0 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_5dd97_row1_col2 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_5dd97_row1_col3, #T_5dd97_row11_col15 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_5dd97_row1_col4, #T_5dd97_row8_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_5dd97_row1_col5, #T_5dd97_row7_col1 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_5dd97_row1_col7 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_5dd97_row1_col9, #T_5dd97_row3_col8 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_5dd97_row1_col10, #T_5dd97_row4_col9, #T_5dd97_row11_col8, #T_5dd97_row13_col9 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_5dd97_row1_col11, #T_5dd97_row12_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_5dd97_row1_col12, #T_5dd97_row5_col13 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_5dd97_row1_col13, #T_5dd97_row9_col12 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_5dd97_row1_col14, #T_5dd97_row12_col10 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_5dd97_row1_col15, #T_5dd97_row10_col13 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_5dd97_row2_col1 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_5dd97_row2_col3, #T_5dd97_row2_col11, #T_5dd97_row12_col2, #T_5dd97_row14_col0 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_5dd97_row2_col4, #T_5dd97_row8_col11 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_5dd97_row2_col6, #T_5dd97_row13_col6 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_5dd97_row2_col7, #T_5dd97_row4_col15 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_5dd97_row2_col8, #T_5dd97_row4_col8, #T_5dd97_row7_col10, #T_5dd97_row11_col9, #T_5dd97_row13_col10 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_5dd97_row2_col9 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_5dd97_row2_col10 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_5dd97_row2_col12 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_5dd97_row2_col13 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_5dd97_row2_col14 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_5dd97_row2_col15 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_5dd97_row3_col0 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_5dd97_row3_col1, #T_5dd97_row4_col14 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_5dd97_row3_col2, #T_5dd97_row9_col11 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_5dd97_row3_col5, #T_5dd97_row13_col8 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_5dd97_row3_col6, #T_5dd97_row3_col7, #T_5dd97_row7_col9 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_5dd97_row3_col9, #T_5dd97_row5_col10, #T_5dd97_row6_col10, #T_5dd97_row12_col13, #T_5dd97_row14_col8, #T_5dd97_row14_col10 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_5dd97_row3_col10, #T_5dd97_row14_col9 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_5dd97_row3_col11, #T_5dd97_row7_col4, #T_5dd97_row8_col3, #T_5dd97_row8_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_5dd97_row3_col12 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_5dd97_row3_col13, #T_5dd97_row7_col13, #T_5dd97_row15_col9 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_5dd97_row3_col14, #T_5dd97_row11_col14 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_5dd97_row4_col0, #T_5dd97_row9_col0, #T_5dd97_row10_col0, #T_5dd97_row14_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_5dd97_row4_col1 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_5dd97_row4_col2, #T_5dd97_row9_col2, #T_5dd97_row14_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_5dd97_row4_col5, #T_5dd97_row11_col1, #T_5dd97_row12_col3 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_5dd97_row4_col6 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_5dd97_row4_col7 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_5dd97_row4_col11 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_5dd97_row4_col12, #T_5dd97_row12_col5, #T_5dd97_row12_col6 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_5dd97_row4_col13, #T_5dd97_row13_col5 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_5dd97_row5_col0 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_5dd97_row5_col1 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_5dd97_row5_col2, #T_5dd97_row11_col6, #T_5dd97_row13_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_5dd97_row5_col3, #T_5dd97_row5_col12, #T_5dd97_row5_col14, #T_5dd97_row6_col12, #T_5dd97_row7_col12 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_5dd97_row5_col6, #T_5dd97_row6_col5 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_5dd97_row5_col7, #T_5dd97_row7_col5 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_5dd97_row5_col8, #T_5dd97_row6_col14 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_5dd97_row5_col9, #T_5dd97_row6_col9 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_5dd97_row5_col11, #T_5dd97_row7_col11 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_5dd97_row5_col15 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_5dd97_row6_col0 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_5dd97_row6_col1 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_5dd97_row6_col2, #T_5dd97_row14_col1 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_5dd97_row6_col3, #T_5dd97_row6_col8, #T_5dd97_row7_col8 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_5dd97_row6_col4, #T_5dd97_row8_col7 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_5dd97_row6_col7, #T_5dd97_row7_col6 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_5dd97_row6_col11, #T_5dd97_row9_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_5dd97_row6_col13 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_5dd97_row6_col15, #T_5dd97_row14_col6 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_5dd97_row7_col0, #T_5dd97_row7_col14 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_5dd97_row7_col2 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_5dd97_row7_col15, #T_5dd97_row12_col14 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_5dd97_row8_col0, #T_5dd97_row13_col2 {
#   bac

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X = dataFrame[['daily_solar_radiation','median_income', 'education_level', 'homeownership','population_density']]
vif_data=pd.DataFrame()
vif_data["solar_system_count_residential"]=X.columns
vif_data["VIF"]=[variance_inflation_factor(X.values, i) for i in range (len(X.columns))]
print(vif_data)
# Out:
#   solar_system_count_residential        VIF
# 0          daily_solar_radiation  16.058428
# 1                  median_income  30.746291
# 2                education_level  11.642603
# 3                  homeownership  48.443142
# 4             population_density   3.883676

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X = dataFrame[['daily_solar_radiation','median_income', 'education_level', 'homeownership','population_density']]
vif_data=pd.DataFrame()
vif_data["solar_system_count_residential"]=X.columns
vif_data["VIF"]=[variance_inflation_factor(X.values, i) for i in range (len(X.columns))]
print(vif_data)
# Out:
#   solar_system_count_residential        VIF
# 0          daily_solar_radiation  16.058428
# 1                  median_income  30.746291
# 2                education_level  11.642603
# 3                  homeownership  48.443142
# 4             population_density   3.883676
